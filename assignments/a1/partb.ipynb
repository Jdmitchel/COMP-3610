# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (1.26.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: matplotlib in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from seaborn) (2.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\jmitc\anaconda3\envs\assignment\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# Out:
# C:\Users\jmitc\AppData\Local\Temp\ipykernel_16068\3313838806.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('top_hollywood_grossing_movies.csv')
df.shape
# Out:
# (900, 11)

# %%
df.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0  Star Wars: Episode VII - The Force Awakens (2015)
# 1           1                           Avengers: Endgame (2019)
# 2           2                                      Avatar (2009)
# 3           3                               Black Panther (2018)
# 4           4                      Avengers: Infinity War (2018)
#
#                                           Movie Info  \
# 0  As a new threat to the galaxy rises, Rey, a de...
# 1  After the devastating events of Avengers: Infi...
# 2  A paraplegic Marine dispatched to the moon Pan...
# 3  T'Challa, heir to the hidden but advanced king...
# 4  The Avengers and their allies must be willing ...
#
#                            Distributor       Release Date  \
# 0  Walt Disney Studios Motion Pictures  December 16, 2015
# 1  Walt Disney Studios Motion Pictures     April 24, 2019
# 2                Twentieth Century Fox  December 16, 2009
# 3  Walt Disney Studios Motion Pictures                NaN
# 4  Walt Disney Studios Motion Pictures                NaN
#
#    Domestic Sales (in $)  International Sales (in $)  World Sales (in $)  \
# 0              936662225                  1132859475          2069521700
# 1              858373000                  1939128328          2797501328
# 2              760507625                  2086738578          2847246203
# 3              700426566                   647171407          1347597973
# 4              678815482                  1369544272          2048359754
#
#                                           Genre Movie Runtime License
# 0             ['Action', 'Adventure', 'Sci-Fi']   2 hr 18 min   PG-13
# 1    ['Action', 'Adventure', 'Drama', 'Sci-Fi']    3 hr 1 min   PG-13
# 2  ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']   2 hr 42 min   PG-13
# 3             ['Action', 'Adventure', 'Sci-Fi']   2 hr 14 min     NaN
# 4             ['Action', 'Adventure', 'Sci-Fi']   2 hr 29 min     NaN

# %%
genre_count = df['Genre'].value_counts()
print(genre_count)
# Out:
# Genre
# ['Action', 'Adventure', 'Sci-Fi']                                      56
# ['Comedy']                                                             34
# ['Comedy', 'Romance']                                                  30
# ['Action', 'Adventure', 'Thriller']                                    28
# ['Action', 'Crime', 'Thriller']                                        23
#                                                                        ..
# ['Action', 'Adventure', 'Drama', 'Fantasy', 'Romance', 'Thriller']      1
# ['Action', 'Adventure', 'Comedy', 'Thriller']                           1
# ['Adventure', 'Animation', 'Comedy', 'Family', 'Romance', 'Sci-Fi']     1
# ['Adventure', 'Comedy', 'Drama', 'Fantasy', 'Musical']                  1
# ['Adventure', 'Comedy', 'Crime', 'Mystery']                             1
# Name: count, Length: 302, dtype: int64

# %%
unique_genres = df['Genre'].unique()
print(unique_genres)
# Out:
# ["['Action', 'Adventure', 'Sci-Fi']"
#  "['Action', 'Adventure', 'Drama', 'Sci-Fi']"
#  "['Action', 'Adventure', 'Fantasy', 'Sci-Fi']" "['Drama', 'Romance']"
#  "['Action', 'Adventure', 'Animation', 'Comedy', 'Family', 'Sci-Fi']"
#  "['Adventure', 'Animation', 'Drama', 'Family', 'Musical']"
#  "['Action', 'Crime', 'Drama', 'Thriller']"
#  "['Adventure', 'Family', 'Fantasy', 'Musical', 'Romance']"
#  "['Adventure', 'Animation', 'Comedy', 'Family']"
#  "['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy', 'Musical']"
#  "['Action', 'Crime', 'Drama']"
#  "['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy', 'Romance']"
#  "['Adventure', 'Family', 'Sci-Fi']"
#  "['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']"
#  "['Action', 'Adventure', 'Drama', 'Sci-Fi', 'Thriller']"
#  "['Action', 'Adventure', 'Fantasy']"
#  "['Action', 'Adventure', 'Fantasy', 'Sci-Fi', 'War']"
#  "['Action', 'Adventure', 'Sci-Fi', 'Thriller']"
#  "['Action', 'Adventure', 'Comedy', 'Fantasy']"
#  "['Action', 'Adventure', 'Comedy', 'Sci-Fi']"
#  "['Adventure', 'Fantasy', 'Mystery']"
#  "['Action', 'Adventure', 'Drama', 'Fantasy']" "['Drama']"
#  "['Adventure', 'Animation', 'Comedy', 'Crime', 'Family', 'Sci-Fi']"
#  "['Adventure', 'Drama', 'Family', 'Fantasy']"
#  "['Adventure', 'Animation', 'Comedy', 'Drama', 'Family', 'Fantasy', 'Sci-Fi']"
#  "['Adventure', 'Comedy', 'Family', 'Fantasy', 'Musical', 'Romance']"
#  "['Action', 'Thriller']" "['Action', 'Biography', 'Drama', 'War']"
#  "['Adventure', 'Animation', 'Comedy', 'Crime', 'Family', 'Mystery']"
#  "['Crime', 'Drama', 'Thriller']"
#  "['Adventure', 'Family', 'Fantasy', 'Mystery']" "['Horror']"
#  "['Adventure', 'Family', 'Fantasy']" "['Action', 'Adventure']"
#  "['Action', 'Adventure', 'Comedy', 'Fantasy', 'Sci-Fi']"
#  "['Action', 'Adventure', 'Thriller']" "['Adventure', 'Fantasy']"
#  "['Action', 'Adventure', 'Family', 'Fantasy', 'Mystery']"
#  "['Action', 'Adventure', 'Drama', 'Fantasy', 'Romance', 'Thriller']"
#  "['Adventure', 'Drama', 'Fantasy', 'Romance']"
#  "['Drama', 'Mystery', 'Thriller']"
#  "['Adventure', 'Animation', 'Comedy', 'Drama', 'Family']"
#  "['Comedy', 'Family']" "['Action', 'Sci-Fi']"
#  "['Adventure', 'Drama', 'Fantasy', 'Romance', 'Thriller']"
#  "['Comedy', 'Romance']" "['Comedy']"
#  "['Action', 'Drama', 'Sci-Fi', 'Thriller']"
#  "['Animation', 'Comedy', 'Family', 'Musical']"
#  "['Action', 'Adventure', 'Animation', 'Family']"
#  "['Adventure', 'Thriller']" "['Comedy', 'Family', 'Fantasy']"
#  "['Action', 'Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy', 'Sci-Fi']"
#  "['Biography', 'Drama', 'Sport']"
#  "['Adventure', 'Comedy', 'Family', 'Fantasy']"
#  "['Adventure', 'Animation', 'Comedy', 'Family', 'Sport']"
#  "['Action', 'Comedy', 'Fantasy', 'Sci-Fi']" "['Comedy', 'Fantasy']"
#  "['Comedy', 'Drama', 'Romance']"
#  "['Adventure', 'Family', 'Fantasy', 'Romance']"
#  "['Action', 'Crime', 'Thriller']" "['Adventure', 'Drama', 'Romance']"
#  "['Adventure', 'Drama', 'Sci-Fi']"
#  "['Drama', 'Mystery', 'Sci-Fi', 'Thriller']"
#  "['Action', 'Drama', 'Fantasy']" "['Action', 'Mystery', 'Thriller']"
#  "['Action', 'Comedy', 'Crime', 'Thriller']"
#  "['Adventure', 'Animation', 'Family', 'Sci-Fi']"
#  "['Action', 'Adventure', 'Mystery', 'Thriller']"
#  "['Adventure', 'Animation', 'Comedy', 'Drama', 'Family', 'Fantasy', 'Music', 'Musical']"
#  "['Comedy', 'Drama', 'Family']"
#  "['Animation', 'Family', 'Fantasy', 'Musical', 'Romance']"
#  "['Action', 'Adventure', 'Drama', 'Romance']"
#  "['Drama', 'Fantasy', 'Romance', 'Thriller']"
#  "['Action', 'Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']"
#  "['Mystery', 'Thriller']"
#  "['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy', 'Musical', 'Romance']"
#  "['Drama', 'War']" "['Biography', 'Drama', 'Music']"
#  "['Drama', 'Music', 'Romance']" "['Action', 'Sci-Fi', 'Thriller']"
#  "['Adventure', 'Animation', 'Comedy', 'Drama', 'Family', 'Fantasy', 'Musical']"
#  "['Action', 'Adventure', 'Comedy', 'Crime']"
#  "['Drama', 'Fantasy', 'Horror']" "['Adventure', 'Comedy', 'Sci-Fi']"
#  "['Action', 'Drama']"
#  "['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy', 'Music', 'Mystery']"
#  "['Action', 'Adventure', 'Mystery']"
#  "['Adventure', 'Comedy', 'Family', 'Fantasy', 'Musical']"
#  "['Action', 'Adventure', 'Horror', 'Sci-Fi']"
#  "['Action', 'Adventure', 'Fantasy', 'Thriller']"
#  "['Adventure', 'Drama', 'Family', 'Fantasy', 'Romance']"
#  "['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy', 'Sci-Fi']"
#  "['Action', 'Drama', 'History', 'Romance', 'War']"
#  "['Adventure', 'Animation', 'Comedy', 'Family', 'Music', 'Musical', 'Romance']"
#  "['Drama', 'Fantasy', 'Romance']"
#  "['Action', 'Adventure', 'Comedy', 'Mystery', 'Sci-Fi']"
#  "['Action', 'Comedy', 'Crime']"
#  "['Action', 'Adventure', 'Animation', 'Comedy', 'Sci-Fi']"
#  "['Comedy', 'Musical', 'Romance']"
#  "['Action', 'Drama', 'History', 'Thriller', 'War']"
#  "['Drama', 'Horror', 'Sci-Fi']" "['Action', 'Adventure', 'Drama']"
#  "['Adventure', 'Animation', 'Family', 'Fantasy', 'Musical', 'Romance']"
#  "['Comedy', 'Music']" "['Adventure', 'Drama', 'Western']"
#  "['Action', 'Crime', 'Drama', 'Mystery', 'Thriller']"
#  "['Action', 'Adventure', 'Drama', 'History', 'Western']"
#  "['Crime', 'Thriller']" "['Adventure', 'Animation', 'Comedy']"
#  "['Comedy', 'Fantasy', 'Romance']"
#  "['Action', 'Adventure', 'Drama', 'Thriller']"
#  "['Biography', 'Drama', 'History', 'War']"
#  "['Adventure', 'Comedy', 'Family', 'Fantasy', 'Romance']"
#  "['Action', 'Drama', 'Family', 'Sport']"
#  "['Horror', 'Mystery', 'Thriller']" "['Biography', 'Drama', 'Musical']"
#  "['Adventure', 'Drama', 'History']"
#  "['Adventure', 'Comedy', 'Crime', 'Family']"
#  "['Action', 'Drama', 'Thriller']" "['Drama', 'Western']"
#  "['Adventure', 'Animation', 'Comedy', 'Drama', 'Family', 'Music']"
#  "['Biography', 'Drama']" "['Comedy', 'Crime', 'Musical']"
#  "['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy', 'Horror']"
#  "['Biography', 'Drama', 'History']" "['Action', 'Adventure', 'Comedy']"
#  "['Drama', 'Romance', 'Thriller']"
#  "['Comedy', 'Crime', 'Drama', 'Mystery', 'Thriller']"
#  "['Biography', 'Crime', 'Drama']" "['Comedy', 'Drama']"
#  "['Action', 'Crime', 'Fantasy']" "['Comedy', 'Sport']"
#  "['Biography', 'Drama', 'History', 'Music']"
#  "['Adventure', 'Animation', 'Comedy', 'Family', 'Thriller']"
#  "['Drama', 'Horror', 'Sci-Fi', 'Thriller']"
#  "['Crime', 'Horror', 'Thriller']" "['Action', 'Drama', 'War']"
#  "['Comedy', 'Crime', 'Sport']"
#  "['Adventure', 'Animation', 'Comedy', 'Crime', 'Family', 'Fantasy', 'Mystery']"
#  "['Drama', 'Horror', 'Mystery', 'Thriller']"
#  "['Adventure', 'Animation', 'Comedy', 'Drama', 'Family', 'Fantasy', 'Music']"
#  "['Comedy', 'Drama', 'Romance', 'Sport']"
#  "['Adventure', 'Comedy', 'Family', 'Fantasy', 'Mystery']"
#  "['Comedy', 'Drama', 'Music', 'Musical', 'Romance']"
#  "['Action', 'Adventure', 'Mystery', 'Sci-Fi']" "['Comedy', 'Crime']"
#  "['Crime', 'Drama']" "['Drama', 'Musical', 'Romance']"
#  "['Action', 'Animation', 'Comedy', 'Crime', 'Family', 'Mystery', 'Sci-Fi', 'Thriller']"
#  "['Animation', 'Comedy', 'Family', 'Fantasy', 'Horror']"
#  "['Action', 'Comedy', 'Crime', 'Family']"
#  "['Action', 'Comedy', 'Thriller']"
#  "['Comedy', 'Drama', 'Family', 'Fantasy']"
#  "['Action', 'Horror', 'Sci-Fi', 'Thriller']"
#  "['Action', 'Mystery', 'Sci-Fi', 'Thriller']"
#  "['Action', 'Adventure', 'Comedy', 'Family', 'Mystery', 'Sci-Fi']"
#  "['Adventure', 'Animation', 'Comedy', 'Family', 'Music', 'Musical']"
#  "['Action', 'Adventure', 'Family', 'Fantasy']"
#  "['Adventure', 'Animation', 'Drama', 'Family', 'Musical', 'Romance']"
#  "['Drama', 'Thriller']" "['Horror', 'Mystery']"
#  "['Comedy', 'Family', 'Music']" "['Horror', 'Thriller']"
#  "['Adventure', 'Animation', 'Comedy', 'Drama', 'Family', 'Fantasy']"
#  "['Adventure', 'Animation', 'Drama', 'Family', 'Fantasy']"
#  "['Comedy', 'Drama', 'Fantasy', 'Romance']"
#  "['Crime', 'Drama', 'Fantasy', 'Mystery']"
#  "['Biography', 'Drama', 'Thriller']"
#  "['Action', 'Adventure', 'Comedy', 'Family', 'Sci-Fi']"
#  "['Biography', 'Comedy', 'Drama', 'Romance']"
#  "['Comedy', 'Crime', 'Drama']" "['Drama', 'History']"
#  "['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy', 'Music', 'Musical']"
#  "['Drama', 'Family']"
#  "['Action', 'Crime', 'Mystery', 'Sci-Fi', 'Thriller']"
#  "['Crime', 'Drama', 'Horror', 'Thriller']"
#  "['Comedy', 'Romance', 'Sci-Fi']"
#  "['Action', 'Adventure', 'Comedy', 'Thriller']"
#  "['Adventure', 'Animation', 'Comedy', 'Family', 'Romance', 'Sci-Fi']"
#  "['Action', 'Adventure', 'Drama', 'Fantasy', 'Romance']"
#  "['Adventure', 'Comedy', 'Drama', 'Fantasy', 'Musical']"
#  "['Drama', 'Sport']" "['Adventure', 'Mystery', 'Sci-Fi']"
#  "['Action', 'Adventure', 'Comedy', 'Crime', 'Thriller']"
#  "['Adventure', 'Comedy', 'Fantasy', 'Sci-Fi']"
#  "['Adventure', 'Drama', 'Fantasy']" "['Comedy', 'Western']"
#  "['Action', 'Adventure', 'Animation', 'Comedy', 'Family', 'Western']"
#  "['Action', 'Drama', 'Music', 'Romance', 'Thriller']"
#  "['Adventure', 'Drama', 'War']" "['Drama', 'History', 'Sport']"
#  "['Action', 'Comedy', 'Crime', 'Fantasy']"
#  "['Biography', 'Drama', 'Music', 'Romance']"
#  "['Documentary', 'Drama', 'War']"
#  "['Action', 'Drama', 'Thriller', 'War']"
#  "['Comedy', 'Drama', 'Musical', 'Romance']"
#  "['Crime', 'Mystery', 'Thriller']"
#  "['Action', 'Biography', 'Drama', 'Sport']"
#  "['Action', 'Comedy', 'Documentary']"
#  "['Action', 'Adventure', 'Crime', 'Thriller']"
#  "['Biography', 'Comedy', 'Crime', 'Drama']" "['Drama', 'Music']"
#  "['Crime', 'Drama', 'Mystery', 'Thriller']"
#  "['Action', 'Fantasy', 'Thriller']"
#  "['Action', 'Biography', 'Drama', 'Sport', 'War']"
#  "['Adventure', 'Animation', 'Comedy', 'Crime', 'Drama', 'Family', 'Fantasy']"
#  "['Adventure', 'Comedy', 'Drama']"
#  "['Adventure', 'Animation', 'Comedy', 'Crime', 'Drama', 'Family', 'Sci-Fi']"
#  "['Action', 'Comedy', 'Sci-Fi', 'Western']"
#  "['Action', 'Drama', 'History', 'War']"
#  "['Action', 'Comedy', 'Drama', 'Family']"
#  "['Action', 'Crime', 'Sci-Fi', 'Thriller']"
#  "['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy', 'History', 'Sci-Fi']"
#  "['Drama', 'Sci-Fi', 'Thriller']" "['Action', 'Comedy']"
#  "['Action', 'Comedy', 'War']"
#  "['Comedy', 'Family', 'Fantasy', 'Music', 'Romance']"
#  "['Adventure', 'Comedy', 'Family', 'Fantasy', 'Romance', 'Sci-Fi']"
#  "['Action', 'Drama', 'Sport']" "['Adventure', 'Comedy', 'Crime']"
#  "['Comedy', 'Family', 'Romance']"
#  "['Action', 'Crime', 'Drama', 'Music', 'Thriller']"
#  "['Comedy', 'Drama', 'Sport']"
#  "['Action', 'Adventure', 'Animation', 'Family', 'Fantasy', 'Mystery']"
#  "['Action', 'Drama', 'Mystery', 'Sci-Fi']"
#  "['Action', 'Adventure', 'Animation', 'Comedy', 'Family']"
#  "['Action', 'Biography', 'Crime', 'Drama', 'Thriller']"
#  "['Action', 'Comedy', 'Crime', 'Romance']"
#  "['Action', 'Adventure', 'Drama', 'History']"
#  "['Action', 'Adventure', 'Comedy', 'Family', 'Romance']"
#  "['Drama', 'Fantasy', 'Romance', 'Sci-Fi']"
#  "['Action', 'Adventure', 'Comedy', 'Family', 'Fantasy', 'Sci-Fi']"
#  "['Action', 'Comedy', 'Crime', 'Music', 'Romance', 'Thriller']"
#  "['Action', 'Adventure', 'Animation', 'Comedy', 'Drama', 'Family', 'Fantasy']"
#  "['Drama', 'Music', 'Musical']" "['Crime', 'Drama', 'Mystery']"
#  "['Action', 'Crime']" "['Action', 'Fantasy', 'Horror', 'War']"
#  "['Action', 'Adventure', 'Family', 'Fantasy', 'Sci-Fi']"
#  "['Action', 'Adventure', 'Comedy', 'Thriller', 'Western']"
#  "['Adventure', 'Animation', 'Drama', 'Family', 'Fantasy', 'Musical']"
#  "['Fantasy', 'Horror', 'Mystery']"
#  "['Fantasy', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller']"
#  "['Drama', 'Sci-Fi']"
#  "['Adventure', 'Animation', 'Comedy', 'Drama', 'Family', 'Musical']"
#  "['Adventure', 'Family', 'Fantasy', 'Sci-Fi']"
#  "['Comedy', 'Drama', 'History', 'Romance']"
#  "['Action', 'Sci-Fi', 'Thriller', 'Western']"
#  "['Animation', 'Drama', 'Family', 'Musical', 'Romance']"
#  "['Drama', 'Romance', 'Sci-Fi', 'Thriller']"
#  "['Comedy', 'Crime', 'Romance', 'Thriller']"
#  "['Adventure', 'Animation', 'Comedy', 'Fantasy']"
#  "['Action', 'Adventure', 'Comedy', 'Crime', 'Family', 'Sci-Fi']"
#  "['Action', 'Biography', 'Crime', 'Drama', 'History']"
#  "['Drama', 'History', 'Thriller', 'War']"
#  "['Adventure', 'Drama', 'History', 'Romance', 'War']"
#  "['Comedy', 'Drama', 'Fantasy']"
#  "['Action', 'Adventure', 'Drama', 'Fantasy', 'History']"
#  "['Adventure', 'Comedy', 'Drama', 'Family', 'Romance']"
#  "['Biography', 'Drama', 'Romance']"
#  "['Action', 'Adventure', 'Comedy', 'Romance', 'Thriller', 'Western']"
#  "['Action', 'Adventure', 'Drama', 'War']"
#  "['Adventure', 'Animation', 'Comedy', 'Family', 'Musical', 'Romance']"
#  "['Action', 'Adventure', 'Family', 'Fantasy', 'Mystery', 'Sci-Fi']"
#  "['Action', 'Adventure', 'Western']"
#  "['Action', 'Comedy', 'Family', 'Fantasy']"
#  "['Action', 'Drama', 'Sci-Fi']" "['Comedy', 'Family', 'Sci-Fi']"
#  "['Animation', 'Comedy', 'Drama', 'Family', 'Fantasy', 'Musical']"
#  "['Action', 'Drama', 'Mystery', 'Sci-Fi', 'Thriller']"
#  "['Biography', 'Drama', 'Family']"
#  "['Fantasy', 'Horror', 'Mystery', 'Thriller']"
#  "['Biography', 'Drama', 'Thriller', 'War']"
#  "['Comedy', 'Family', 'Sport']"
#  "['Comedy', 'Drama', 'Family', 'Music', 'Musical', 'Romance']"
#  "['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy', 'Sci-Fi', 'Sport']"
#  "['Adventure', 'Comedy', 'Family', 'Musical']"
#  "['Adventure', 'Comedy', 'Sci-Fi', 'Western']"
#  "['Action', 'Crime', 'Romance', 'Thriller']"
#  "['Adventure', 'Animation', 'Family', 'Fantasy', 'Musical']"
#  "['Adventure', 'Drama', 'Family', 'Fantasy', 'Thriller']"
#  "['Adventure', 'Comedy', 'Crime', 'Drama']"
#  "['Comedy', 'Drama', 'Family', 'Musical']"
#  "['Action', 'Adventure', 'Animation', 'Family', 'Fantasy', 'Sci-Fi']"
#  "['Action', 'Drama', 'Sci-Fi', 'Sport']" "['Comedy', 'War']"
#  "['Biography', 'Comedy', 'Drama', 'Music']"
#  "['Adventure', 'Comedy', 'Family', 'Fantasy', 'Horror', 'Mystery', 'Sci-Fi']"
#  "['Adventure', 'Animation', 'Comedy', 'Family', 'Sci-Fi']"
#  "['Action', 'Drama', 'Fantasy', 'Romance']"
#  "['Biography', 'Drama', 'Family', 'Music']" "['Drama', 'Mystery', 'War']"
#  "['Biography', 'Comedy', 'Drama']" "['Adventure', 'Comedy']"
#  "['Action', 'Horror']" "['Adventure', 'Comedy', 'Family']"
#  "['Drama', 'Fantasy', 'Horror', 'Romance']"
#  "['Action', 'Adventure', 'Animation', 'Fantasy']"
#  "['Drama', 'Family', 'Fantasy']"
#  "['Adventure', 'Comedy', 'Crime', 'Mystery']"]
